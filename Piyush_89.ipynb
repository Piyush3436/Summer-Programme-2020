# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
#importing the file and plotting the correlation heatmap 
train=pd.read_csv('Trainfile.csv')
train=train.fillna(train.mean())
train.corr()
f,ax=plt.subplots(figsize=(20,20))
sns.heatmap(train.corr())

# %%
train.corr()
# Out:
#                     Idx  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Idx            1.000000   -0.006606    -0.002936 -0.039157    -0.038094
# MSSubClass    -0.006606    1.000000    -0.331826 -0.209666     0.031498
# LotFrontage   -0.002936   -0.331826     1.000000  0.355560     0.252266
# LotArea       -0.039157   -0.209666     0.355560  1.000000     0.140049
# OverallQual   -0.038094    0.031498     0.252266  0.140049     1.000000
# OverallCond    0.009082   -0.058665    -0.051054 -0.023674    -0.106355
# YearBuilt     -0.017630    0.016648     0.124637  0.031084     0.556155
# YearRemodAdd   0.005956    0.027125     0.106423  0.048485     0.551615
# MasVnrArea    -0.031179    0.038160     0.184852  0.160335     0.393395
# BsmtFinSF1    -0.031634   -0.077084     0.223539  0.233037     0.196045
# BsmtFinSF2    -0.002135   -0.059197     0.026631  0.034102    -0.054055
# BsmtUnfSF      0.036895   -0.139154     0.129841  0.035230     0.335999
# ...

# %%
#the variable features has been used frequently and updated every time a change in the dataframe is made
features=list(train.columns)

# %%
#creating a list of all the features containing integer or float variables
piyush=[]
for i in range(len(train.columns)):
    if train[features[i]].dtype!='O':
        print(features[i])
        piyush.append(features[i])
# Out:
# Idx
# MSSubClass
# LotFrontage
# LotArea
# OverallQual
# OverallCond
# YearBuilt
# YearRemodAdd
# MasVnrArea
# BsmtFinSF1
# BsmtFinSF2
# BsmtUnfSF
# TotalBsmtSF
# 1stFlrSF
# 2ndFlrSF
# LowQualFinSF
# GrLivArea
# BsmtFullBath
# BsmtHalfBath
# FullBath
# HalfBath
# BedroomAbvGr
# KitchenAbvGr
# TotRmsAbvGrd
# Fireplaces
# GarageYrBlt
# GarageCars
# GarageArea
# WoodDeckSF
# OpenPorchSF
# EnclosedPorch
# 3SsnPorch
# ScreenPorch
# PoolArea
# MiscVal
# MoSold
# YrSold
# SalePrice

# %%
print(piyush)
# Out:
# ['Idx', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']

# %%
#Dropping all the features having a lesser correlation with Saleprice
train=train.drop(['Idx', 'MSSubClass', 'LotFrontage', 'LotArea', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF','BsmtFullBath', 'BsmtHalfBath','HalfBath', 'BedroomAbvGr','Fireplaces', 'GarageYrBlt','WoodDeckSF', 'OpenPorchSF','3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold'],axis=1)

# %%
features=list(train.columns)

# %%
Nan=list(train.isnull().sum())

# %%
for i in range(len(train.columns)):
    print(features[i]+' : '+str(Nan[i]))
# Out:
# MSZoning : 0
# Street : 0
# Alley : 1072
# LotShape : 0
# LandContour : 0
# Utilities : 0
# LotConfig : 0
# LandSlope : 0
# Neighborhood : 0
# Condition1 : 0
# Condition2 : 0
# BldgType : 0
# HouseStyle : 0
# OverallQual : 0
# OverallCond : 0
# RoofStyle : 0
# RoofMatl : 0
# Exterior1st : 0
# Exterior2nd : 0
# MasVnrType : 6
# ExterQual : 0
# ExterCond : 0
# Foundation : 0
# BsmtQual : 30
# BsmtCond : 30
# BsmtExposure : 31
# BsmtFinType1 : 30
# BsmtFinType2 : 31
# Heating : 0
# HeatingQC : 0
# CentralAir : 0
# Electrical : 1
# GrLivArea : 0
# FullBath : 0
# KitchenAbvGr : 0
# KitchenQual : 0
# TotRmsAbvGrd : 0
# Functional : 0
# FireplaceQu : 540
# GarageType : 68
# GarageFinish : 68
# GarageCars : 0
# GarageArea : 0
# GarageQual : 68
# GarageCond : 68
# PavedDrive : 0
# EnclosedPorch : 0
# PoolQC : 1133
# Fence : 914
# MiscFeature : 1096
# SaleType : 0
# SaleCondition : 0
# SalePrice : 0

# %%
#Dropping all the features having more than 900 missing values
train=train.drop(['Alley','FireplaceQu','MiscFeature','PoolQC','Fence'],axis=1)
train.head()
# Out:
#   MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave      Reg         HLS    AllPub    Corner       Mod
# 1       RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 2       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 4       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#   Neighborhood Condition1 Condition2  ... GarageFinish GarageCars  GarageArea  \
# 0        NAmes     Artery       Norm  ...          Unf          2         528
# 1       NWAmes       PosN       Norm  ...          Fin          2         619
# 2       Sawyer       Norm       Norm  ...          Fin          1         288
# 3       Timber       Norm       Norm  ...          Fin          3         642
# 4      NridgHt       Norm       Norm  ...          Fin          3         672
#
#    GarageQual GarageCond PavedDrive EnclosedPorch SaleType SaleCondition  \
# ...

# %%
features=list(train.columns)

# %%
#Getting a variable count of every feature to understand the variation
for i in range(len(train.columns)):
    if train[features[i]].dtype=='O':
        print(train[features[i]].value_counts())
# Out:
# RL         906
# RM         167
# FV          44
# RH          12
# C (all)      9
# Name: MSZoning, dtype: int64
# Pave    1133
# Grvl       5
# Name: Street, dtype: int64
# Reg    727
# IR1    375
# IR2     30
# IR3      6
# Name: LotShape, dtype: int64
# Lvl    1015
# Bnk      52
# HLS      44
# Low      27
# Name: LandContour, dtype: int64
# AllPub    1138
# Name: Utilities, dtype: int64
# Inside     828
# Corner     203
# CulDSac     69
# FR2         35
# FR3          3
# Name: LotConfig, dtype: int64
# Gtl    1080
# Mod      48
# Sev      10
# Name: LandSlope, dtype: int64
# NAmes      176
# CollgCr    119
# OldTown     89
# Edwards     79
# Gilbert     65
# NridgHt     64
# Somerst     62
# NWAmes      60
# Sawyer      54
# SawyerW     46
# Crawfor     42
# Mitchel     40
# BrkSide     39
# NoRidge     32
# IDOTRR      30
# Timber      26
# ClearCr     22
# SWISU       18
# StoneBr     17
# MeadowV     15
# Blmngtn     14
# BrDale      12
# NPkVill      8
# Veenker      7
# ...

# %%
#Eliminating all the features having a single variable dominance
train=train.drop(['MSZoning','Street','LandContour','Utilities','LandSlope','Condition1','Condition2','BldgType','RoofStyle','RoofMatl','BsmtCond','BsmtFinType2','Heating','CentralAir','Functional','GarageQual','GarageCond','SaleType','SaleCondition'],axis=1)

# %%
print(len(train.columns))
# Out:
# 29

# %%
features=list(train.columns)

# %%
#filling all the missing values in the remaining string variables with the mode
#missing non-string values have been updated with mean above 
for column in train.columns:
    train[column].fillna(train[column].mode()[0], inplace=True)

# %%
for i in range(len(train.columns)):
    if train[features[i]].dtype=='O':
        print(features[i])
# Out:
# LotShape
# LotConfig
# Neighborhood
# HouseStyle
# Exterior1st
# Exterior2nd
# MasVnrType
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtExposure
# BsmtFinType1
# HeatingQC
# Electrical
# KitchenQual
# GarageType
# GarageFinish
# PavedDrive

# %%
#Label encoding the string features 
#tried one hot encoding but didn't add to the accuracy
for i in range(len(train.columns)):
    if train[features[i]].dtype=='O':
        label_encoder = LabelEncoder()  
        train[features[i]]= label_encoder.fit_transform(train[features[i]]) 
        print(train[features[i]].unique())
# Out:
# [3 0 2 1]
# [0 4 1 2 3]
# [12 14 19 23 16 15 21 20 17  7  8  5 10 13  0  3  9 22 11  6  4 24 18  2
#   1]
# [1 5 2 6 0 7 4 3]
# [ 7  5 11  6  4  2 12  8 13  1 10  0  3  9]
# [ 8  6 13  7  5 14 10 15  1 12  2  3  0 11  4  9]
# [2 1 3 0]
# [3 2 0 1]
# [3 2 1 0]
# [1 2 0 3 4 5]
# [3 2 0 1]
# [3 1 0 2]
# [5 0 2 1 4 3]
# [2 4 0 3 1]
# [4 0 1 3 2]
# [2 3 0 1]
# [5 1 3 2 4 0]
# [2 0 1]
# [2 0 1]

# %%
#plotting another heatmap for understanding the correlation of string features
train.corr()
f,ax=plt.subplots(figsize=(20,20))
sns.heatmap(train.corr())

# %%
train.head()
# Out:
#    LotShape  LotConfig  Neighborhood  HouseStyle  OverallQual  OverallCond  \
# 0         3          0            12           1            6            6
# 1         0          0            14           5            6            7
# 2         3          4            19           2            5            7
# 3         0          4            23           5            8            5
# 4         3          4            16           2           10            5
#
#    Exterior1st  Exterior2nd  MasVnrType  ExterQual  ...  KitchenAbvGr  \
# 0            7            8           2          3  ...             1
# 1            5            6           1          3  ...             1
# 2            5            6           1          3  ...             1
# 3           11           13           1          2  ...             1
# 4           11           13           3          0  ...             1
#
#    KitchenQual  TotRmsAbvGrd  GarageType  GarageFinish  GarageCars  \
# ...

# %%
features=list(train.columns)
print(features)
# Out:
# ['LotShape', 'LotConfig', 'Neighborhood', 'HouseStyle', 'OverallQual', 'OverallCond', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtExposure', 'BsmtFinType1', 'HeatingQC', 'Electrical', 'GrLivArea', 'FullBath', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'GarageType', 'GarageFinish', 'GarageCars', 'GarageArea', 'PavedDrive', 'EnclosedPorch', 'SalePrice']

# %%
#Dropping the features having  less correlation
train=train.drop(['LotConfig', 'Neighborhood', 'HouseStyle','OverallCond', 'Exterior1st', 'Exterior2nd', 'MasVnrType','ExterCond','BsmtExposure', 'BsmtFinType1', 'HeatingQC', 'Electrical','KitchenAbvGr', 'GarageType','PavedDrive', 'EnclosedPorch'],axis=1)

# %%
train.head()
# Out:
#    LotShape  OverallQual  ExterQual  Foundation  BsmtQual  GrLivArea  \
# 0         3            6          3           1         3        832
# 1         0            6          3           1         2       2872
# 2         3            5          3           2         3        899
# 3         0            8          2           2         2       2482
# 4         3           10          0           2         0       2402
#
#    FullBath  KitchenQual  TotRmsAbvGrd  GarageFinish  GarageCars  GarageArea  \
# 0         1            2             4             2           2         528
# 1         2            3            11             0           2         619
# 2         1            2             5             0           1         288
# 3         2            2             9             0           3         642
# 4         2            0            10             0           3         672
#
#    SalePrice
# 0     105500
# 1     272000
# 2     130000
# 3     281213
# 4     555000

# %%
features=list(train.columns)

# %%
print(len(train.columns))
# Out:
# 13

# %%
#Normalising the data
train=(train-train.mean())/train.std()
train.head()
# Out:
#    LotShape  OverallQual  ExterQual  Foundation  BsmtQual  GrLivArea  \
# 0  0.743227    -0.081216   0.658133   -0.559981  0.820766  -1.291637
# 1 -1.387233    -0.081216   0.658133   -0.559981 -0.348235   2.564943
# 2  0.743227    -0.808965   0.658133    0.828382  0.820766  -1.164974
# 3 -1.387233     1.374282  -0.763035    0.828382 -0.348235   1.827656
# 4  0.743227     2.829780  -3.605370    0.828382 -2.686236   1.676417
#
#    FullBath  KitchenQual  TotRmsAbvGrd  GarageFinish  GarageCars  GarageArea  \
# 0 -1.012879    -0.407618     -1.551337      0.943636    0.328271    0.264859
# 1  0.808063     0.791010      2.726251     -1.542146    0.328271    0.682629
# 2 -1.012879    -0.407618     -0.940253     -1.542146   -0.987124   -0.836953
# 3  0.808063    -0.407618      1.504083     -1.542146    1.643666    0.788220
# 4  0.808063    -2.804872      2.115167     -1.542146    1.643666    0.925946
#
#    SalePrice
# 0  -0.963285
# 1   1.209134
# 2  -0.643619
# 3   1.329341
# 4   4.901594

# %%
len(train.columns)
# Out:
# 13

# %%
#Setting up elements for model
X=train.iloc[:,0:-1]
ones=np.ones([X.shape[0],1])
X=np.concatenate((ones,X),axis=1)
y=train.iloc[:,12:13].values
theta=np.zeros([1,13])
alpha=0.001
iters=700

# %%
#The model
def computeCost(X,y,theta):
    tobesummed = np.power(((X @ theta.T)-y),2)
    return np.sum(tobesummed)/(2 * len(X))
def gradientDescent(X,y,theta,iters,alpha):
    cost = np.zeros(iters)
    for i in range(iters):
        theta = theta - (alpha/len(X)) * np.sum(X * (X @ theta.T - y), axis=0)
        cost[i] = computeCost(X, y, theta)
    
    return theta,cost

#running the gd and cost function
g,cost = gradientDescent(X,y,theta,iters,alpha)
print(g)

finalCost = computeCost(X,y,g)
print(finalCost)
fig, ax = plt.subplots()  
ax.plot(np.arange(iters), cost, 'r')  
ax.set_xlabel('Iterations')  
ax.set_ylabel('Cost')  
ax.set_title('Cost vs. Iterations')
# Out:
# [[ 6.41548911e-18 -4.48508250e-02  1.72400554e-01 -1.07356630e-01
#    3.75726555e-02 -1.11700170e-01  1.48505321e-01  7.87690915e-02
#   -1.07971267e-01  9.31064758e-02 -8.24703969e-02  1.05925795e-01
#    1.07049989e-01]]
# 0.12211153853666162
# Text(0.5, 1.0, 'Cost vs. Iterations')

# %%
#configuring the train dataframe
test=pd.read_csv('Testfile.csv')
test=test.fillna(test.mean())
test=test.drop(['LotConfig', 'Neighborhood', 'HouseStyle','OverallCond', 'Exterior1st', 'Exterior2nd', 'MasVnrType','ExterCond','BsmtExposure', 'BsmtFinType1', 'HeatingQC', 'Electrical','KitchenAbvGr', 'GarageType','PavedDrive', 'EnclosedPorch'],axis=1)
test=test.drop(['MSZoning','Street','LandContour','Utilities','LandSlope','Condition1','Condition2','BldgType','RoofStyle','RoofMatl','BsmtCond','BsmtFinType2','Heating','CentralAir','Functional','GarageQual','GarageCond','SaleType','SaleCondition'],axis=1)
test=test.drop(['Alley','FireplaceQu','MiscFeature','PoolQC','Fence'],axis=1)
test=test.drop(['Idx', 'MSSubClass', 'LotFrontage', 'LotArea', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF','BsmtFullBath', 'BsmtHalfBath','HalfBath', 'BedroomAbvGr','Fireplaces', 'GarageYrBlt','WoodDeckSF', 'OpenPorchSF','3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold'],axis=1)

# %%
for column in train.columns:
    test[column].fillna(test[column].mode()[0], inplace=True)

# %%
features=list(test.columns)

# %%
for i in range(len(test.columns)):
    if test[features[i]].dtype=='O':
        label_encoder = LabelEncoder()  
        test[features[i]]= label_encoder.fit_transform(test[features[i]]) 
        print(test[features[i]].unique())
# Out:
# [3 1 0 2]
# [2 1 0]
# [1 2 3 0 4]
# [3 2 0 1]
# [3 2 0 1]
# [2 0 1]

# %%
test=(test-test.mean())/test.std()

# %%
#Setting up elements for testing the data
X1=test.iloc[:,0:-1]
ones=np.ones([X1.shape[0],1])
X1=np.concatenate((ones,X1),axis=1)
y1=test.iloc[:,12:13].values
y_pred = X1 @ g.T

# %%
#MAPE function
def mape(y,y_pred):
    mape = ( 100 / len(y) ) * sum( abs( (y-y_pred)) / y )
    return mape
MAPE= mape(y1,y_pred)
print(MAPE)
# Out:
# [11.63119308]

# %%
#A plot to show the realtion in the true and predicted dataset
plt.plot(y1)
plt.plot(y_pred)
plt.legend(["true", "pred"])
plt.show()

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y1,y_pred)
# Out:
# 0.31620821020718376
